# %%
print("="*40)
print("         MY PYTHON PASSPORT      ")
print("="*40)

Name = input("What is your name?")
Course = input("What course are you pursuing?")
Goal = input("What is your dream career?")
Reason = input("What is the reason?")

print("\n"+"="*40)
print("         MY CODING JOURNEY      ")
print("="*40)

print("Name :", Name)
print("Course :", Course)
print("Goal :", Goal)
print("Why? :", Reason)

print("\n"+"="*40)
print("         PYTHON ODYSSEY BEGINS      ")
print("="*40)
# Out:
# ...
#          MY PYTHON PASSPORT
# ...
# What is your name? Saraswathi Priyanka
# What course are you pursuing? MSc Data Science
# What is your dream career? Data Scientist
# What is the reason? Love to work with DATA
# ...
#          MY CODING JOURNEY
# ...
# Name : Saraswathi Priyanka
# Course : MSc Data Science
# Goal : Data Scientist
# Why? : Love to work with DATA
#
# ...
#          PYTHON ODYSSEY BEGINS
# ...
